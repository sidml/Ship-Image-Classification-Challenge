# %%
import fastai
from fastai.vision import *

# %%
path = '../input/game-of-deep-learning-ship-datasets/train/'

# %%
src = ImageList.from_csv(path,'train.csv', folder='images',
                   suffix='').split_by_rand_pct(0.2).\
                    label_from_df()

# %%
tfms = get_transforms(flip_vert=False, max_lighting=0.1, max_zoom=1.05, max_warp=0.)

# %%
data = (src.transform(tfms, size=128)
        .databunch().normalize(imagenet_stats))

# %%
data.show_batch(rows=3, figsize=(12,9))

# %%
arch = models.resnet101

# %%
from torch import nn
import torch.nn.functional as F

class FocalLoss(nn.Module):
    def __init__(self, alpha=1, gamma=2, logits=False, reduction='elementwise_mean'):
        super(FocalLoss, self).__init__()
        self.alpha = alpha
        self.gamma = gamma
        self.logits = logits
        self.reduction = reduction

    def forward(self, inputs, targets):
        if self.logits:
            BCE_loss = F.binary_cross_entropy_with_logits(inputs, targets, reduction='none')
        else:
            BCE_loss = F.binary_cross_entropy(inputs, targets, reduction='none')
        pt = torch.exp(-BCE_loss)
        F_loss = self.alpha * (1-pt)**self.gamma * BCE_loss

        if self.reduction is None:
            return F_loss
        else:
            return torch.mean(F_loss)

# %%
# fbeta_binary = fbeta_binary_me(1)
learn = cnn_learner(data, arch,model_dir="/kaggle/working/")
learn.loss_fn = FocalLoss()
# Out:
# Downloading: "https://download.pytorch.org/models/resnet101-5d3b4d8f.pth" to /tmp/.torch/models/resnet101-5d3b4d8f.pth
# 178728960it [00:02, 66865371.32it/s]

# %%
learn.lr_find()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
lr = 0.01

# %%
learn.fit_one_cycle(20, slice(lr))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.918944</td>
#       <td>0.614258</td>
#       <td>00:31</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.694194</td>
#       <td>0.502390</td>
#       <td>00:29</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.532753</td>
#       <td>0.427474</td>
#       <td>00:29</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.468249</td>
#       <td>0.335605</td>
#       <td>00:29</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.397220</td>
#       <td>0.338512</td>
#       <td>00:29</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.335690</td>
#       <td>0.305575</td>
#       <td>00:29</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.291355</td>
#       <td>0.295695</td>
#       <td>00:29</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.245601</td>
#       <td>0.236174</td>
#       <td>00:29</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.237625</td>
#       <td>0.323807</td>
#       <td>00:29</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.204689</td>
#       <td>0.289202</td>
#       <td>00:29</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.193368</td>
#       <td>0.262278</td>
#       <td>00:28</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.159121</td>
#       <td>0.250777</td>
#       <td>00:29</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.135832</td>
#       <td>0.271725</td>
#       <td>00:29</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.111609</td>
#       <td>0.284857</td>
#       <td>00:29</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.098847</td>
#       <td>0.235663</td>
#       <td>00:28</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.090802</td>
#       <td>0.236732</td>
#       <td>00:28</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.076372</td>
#       <td>0.227801</td>
#       <td>00:28</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.067961</td>
#       <td>0.240265</td>
#       <td>00:29</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.057125</td>
#       <td>0.243231</td>
#       <td>00:29</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.057682</td>
#       <td>0.245901</td>
#       <td>00:29</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage-1-rn50')

# %%
interp = ClassificationInterpretation.from_learner(learn)
interp.plot_confusion_matrix(title='Confusion matrix')

# %%
learn.unfreeze()

# %%
learn.lr_find()
learn.recorder.plot()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.fit_one_cycle(20, slice(1e-5, lr/5))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.066572</td>
#       <td>0.248225</td>
#       <td>00:31</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.082419</td>
#       <td>0.303807</td>
#       <td>00:31</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.137917</td>
#       <td>0.360650</td>
#       <td>00:31</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.182644</td>
#       <td>0.292057</td>
#       <td>00:30</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.188449</td>
#       <td>0.372198</td>
#       <td>00:30</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.163843</td>
#       <td>0.340416</td>
#       <td>00:30</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.141077</td>
#       <td>0.245932</td>
#       <td>00:31</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.124730</td>
#       <td>0.249997</td>
#       <td>00:31</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.122424</td>
#       <td>0.290097</td>
#       <td>00:31</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.110001</td>
#       <td>0.256247</td>
#       <td>00:31</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.091316</td>
#       <td>0.194800</td>
#       <td>00:31</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.064404</td>
#       <td>0.245078</td>
#       <td>00:31</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.050024</td>
#       <td>0.239078</td>
#       <td>00:31</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.033316</td>
#       <td>0.204468</td>
#       <td>00:31</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.026015</td>
#       <td>0.212440</td>
#       <td>00:30</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.018535</td>
#       <td>0.235867</td>
#       <td>00:31</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.017101</td>
#       <td>0.206709</td>
#       <td>00:31</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.013121</td>
#       <td>0.204987</td>
#       <td>00:30</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.007361</td>
#       <td>0.208106</td>
#       <td>00:31</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.008910</td>
#       <td>0.204028</td>
#       <td>00:31</td>
#     </tr>
#   </tbody>
# </table>

# %%
data = (src.transform(tfms, size=256)
        .databunch().normalize(imagenet_stats))

learn.data = data
data.train_ds[0][0].shape
# Out:
# torch.Size([3, 256, 256])

# %%
learn.freeze()

# %%
learn.lr_find()
learn.recorder.plot()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
lr=1e-2/2

# %%
learn.fit_one_cycle(20, slice(lr))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.188481</td>
#       <td>0.237213</td>
#       <td>01:13</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.159757</td>
#       <td>0.168568</td>
#       <td>01:11</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.106434</td>
#       <td>0.145897</td>
#       <td>01:12</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.091524</td>
#       <td>0.130186</td>
#       <td>01:11</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.078440</td>
#       <td>0.142441</td>
#       <td>01:12</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.059647</td>
#       <td>0.182609</td>
#       <td>01:10</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.048177</td>
#       <td>0.149266</td>
#       <td>01:10</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.047098</td>
#       <td>0.150701</td>
#       <td>01:10</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.038744</td>
#       <td>0.158331</td>
#       <td>01:09</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.033110</td>
#       <td>0.156495</td>
#       <td>01:09</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.028487</td>
#       <td>0.154012</td>
#       <td>01:08</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.026101</td>
#       <td>0.188958</td>
#       <td>01:10</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.018924</td>
#       <td>0.199325</td>
#       <td>01:09</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.018536</td>
#       <td>0.168666</td>
#       <td>01:08</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.013462</td>
#       <td>0.162218</td>
#       <td>01:08</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.012037</td>
#       <td>0.160529</td>
#       <td>01:09</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.010531</td>
#       <td>0.172199</td>
#       <td>01:08</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.007431</td>
#       <td>0.167360</td>
#       <td>01:07</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.006003</td>
#       <td>0.166789</td>
#       <td>01:07</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.009733</td>
#       <td>0.162517</td>
#       <td>01:08</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage-1-256-rn50')

# %%
interp = ClassificationInterpretation.from_learner(learn)
interp.plot_confusion_matrix(title='Confusion matrix')

# %%
learn.unfreeze()

# %%
learn.fit_one_cycle(30, slice(1e-5, lr/5))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.013372</td>
#       <td>0.173807</td>
#       <td>01:13</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.014020</td>
#       <td>0.158318</td>
#       <td>01:13</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.018329</td>
#       <td>0.244918</td>
#       <td>01:13</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.031485</td>
#       <td>0.188914</td>
#       <td>01:12</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.049555</td>
#       <td>0.219301</td>
#       <td>01:14</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.066143</td>
#       <td>0.189061</td>
#       <td>01:14</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.065145</td>
#       <td>0.196082</td>
#       <td>01:12</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.075204</td>
#       <td>0.235331</td>
#       <td>01:12</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.065111</td>
#       <td>0.209719</td>
#       <td>01:14</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.064669</td>
#       <td>0.282127</td>
#       <td>01:16</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.056391</td>
#       <td>0.155293</td>
#       <td>01:15</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.045876</td>
#       <td>0.135936</td>
#       <td>01:16</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.049544</td>
#       <td>0.166663</td>
#       <td>01:17</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.042184</td>
#       <td>0.182300</td>
#       <td>01:17</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.037824</td>
#       <td>0.168298</td>
#       <td>01:17</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.032809</td>
#       <td>0.146846</td>
#       <td>01:17</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.022827</td>
#       <td>0.168794</td>
#       <td>01:17</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.021812</td>
#       <td>0.148072</td>
#       <td>01:17</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.018908</td>
#       <td>0.130440</td>
#       <td>01:17</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.013759</td>
#       <td>0.139445</td>
#       <td>01:17</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.009437</td>
#       <td>0.135506</td>
#       <td>01:18</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.010162</td>
#       <td>0.143180</td>
#       <td>01:16</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.004510</td>
#       <td>0.122991</td>
#       <td>01:18</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.004135</td>
#       <td>0.143088</td>
#       <td>01:19</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.003821</td>
#       <td>0.135975</td>
#       <td>01:17</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.002901</td>
#       <td>0.135525</td>
#       <td>01:15</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.001312</td>
#       <td>0.133042</td>
#       <td>01:14</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.002368</td>
#       <td>0.135232</td>
#       <td>01:14</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.001364</td>
#       <td>0.128196</td>
#       <td>01:15</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.001943</td>
#       <td>0.125943</td>
#       <td>01:14</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.recorder.plot_losses()

# %%
learn.save('stage-2-256-rn50')

# %%
learn.export('/kaggle/working/fastai_resnet.pkl')

# %%
interp = ClassificationInterpretation.from_learner(learn)
interp.plot_confusion_matrix(title='Confusion matrix')

# %%
test = ImageList.from_folder('../input/avgameofdltestjpg/test-jpg/')
len(test)
# Out:
# 2680

# %%
learn = load_learner('/kaggle/working/','fastai_resnet.pkl', test=test)
preds, _ = learn.get_preds(ds_type=DatasetType.Test)

# %%
preds[:5]
# Out:
# tensor([[5.6281e-07, 1.2966e-08, 5.2596e-10, 6.3708e-10, 1.0000e+00],
#         [5.0678e-05, 9.9995e-01, 2.8363e-06, 5.0542e-08, 2.6005e-09],
#         [3.0980e-08, 1.0000e+00, 4.4741e-08, 3.2547e-07, 6.5916e-07],
#         [9.9997e-01, 5.7087e-06, 4.3046e-07, 2.4267e-05, 8.3568e-07],
#         [3.3818e-06, 2.5138e-08, 4.5518e-08, 3.3011e-08, 1.0000e+00]])

# %%
labelled_preds = torch.argmax(preds,1)+1

# %%
# thresh = 0.2
# labelled_preds = [' '.join([learn.data.classes[i] for i,p in enumerate(pred) if p > thresh]) for pred in preds]

# %%
fnames = [f.name for f in learn.data.test_ds.items]

# %%
df = pd.DataFrame({'image':fnames, 'category':labelled_preds}, columns=['image', 'category'])

# %%
df.to_csv('submission.csv', index=False)

# %%
df.head()
# Out:
#          image  category
# 0  2792439.jpg         5
# 1  2843625.jpg         2
# 2  2208112.jpg         2
# 3  2802558.jpg         1
# 4  2806712.jpg         5

# %%
df.tail()
# Out:
#             image  category
# 2675   676917.jpg         4
# 2676  2782175.jpg         1
# 2677  2839601.jpg         1
# 2678  2892508.jpg         1
# 2679   952113.jpg         4

# %%
df['class1_prob'] = preds[:,0].numpy()
df['class2_prob'] = preds[:,1].numpy()
df['class3_prob'] = preds[:,2].numpy()
df['class4_prob'] = preds[:,3].numpy()
df['class5_prob'] = preds[:,4].numpy()
df.to_csv('raw_prob.csv', index=False)
